# %% [markdown]
# My first project in captone.

# %% [raw]
# import pandas as pd

# %%
import numpy as np

# %%
import pandas as pd

# %%
print ("hello capstone projects")
# Out:
# hello capstone projects
